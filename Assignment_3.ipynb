# %%
import numpy as np

# %%
import pandas as pd

# %%
auto_data=pd.read_csv('/content/StudentsPerformance.csv')

# %%
auto_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Find out how many males and females participated in the test

# %%
auto_data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# What do you think about the students' parental level of education?

# %%
auto_data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
#Analysis:most of the parents become graduated

# %%
#Who scores the most on average for math, reading and writing based on
● Gender
● Test preparation course

# %%
auto_data[['gender','math score','reading score','writing score']].groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
#analysis :Females score more in reading and writing

# %%
auto_data[['test preparation course','math score','reading score','writing score']].groupby('test preparation course').mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
#Analysis:majority students completed test preparation course

# %%
#What do you think about the scoring variation for math, reading and writing
based on
● Gender
● Test preparation course

# %%
auto_data[['gender','math score','reading score','writing score']].groupby('gender').var()
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
#Analysis:scoring variance is more for female than male

# %%
auto_data[['test preparation course','math score','reading score','writing score']].groupby('test preparation course').var()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %%
#Analysis: majority students are not completed test preparation course

# %%
#The management needs your help to give bonus points to the top 25% of
students based on their math score, so how will you help the management
to achieve this.

# %%
cut_off=auto_data['math score'].quantile(0.75)

# %%
cut_off
# Out:
# 77.0

# %%
top_students=auto_data[auto_data['math score']>cut_off]

# %%
top_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...
